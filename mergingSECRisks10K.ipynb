# %%
#C:\Users\Mousumi Das\Desktop\SECRiskFac\1secRisks10K
    #11a,11b

# %%
#merge all the csv files
import pandas as pd
#df1= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\13secRisks10K.csv')

# %%
df11a= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\11asecRisks10K.csv')
df11b= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\11bsecRisks10K.csv')
df11= pd.concat([df11a, df11b], axis=0)

# %%
df11.shape
# Out:
# (5000, 24)

# %%
df1= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\1secRisks10K.csv')
df2= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\2secRisks10K.csv')
df3= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\3secRisks10K.csv')
df4= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\4secRisks10K.csv')
df5= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\5secRisks10K.csv')
df6= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\6secRisks10K.csv')
df7= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\7secRisks10K.csv')
df8= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\8secRisks10K.csv')
df9= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\9secRisks10K.csv')
df10= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\10secRisks10K.csv')
# df11a= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\11asecRisks10K.csv')
# df11b= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\11bsecRisks10K.csv')
df12= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\12secRisks10K.csv')
df13= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\13secRisks10K.csv')
df14= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\14secRisks10K.csv')
df15= pd.read_csv(r'C:\Users\Mousumi Das\Desktop\SECRiskFac\15secRisks10K.csv')

# %%
df_all = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15], axis=0)

# %%
df_all.shape
# Out:
# (77346, 24)

# %%
df_all.shape
# Out:
# (77346, 22)

# %%
# Create the full file path
file_path = r'D:\SEC_RiskData\risks.csv' #folder_path + file_name

# Save the DataFrame as a CSV file in the specified folder
df_all.to_csv(file_path, index=False)

# %%
df_all.tail(1)
# Out:
#                                      id           accessionNo      cik ticker  \
# 77345  f18ddcaeef0a2485c4be5570750fc362  0000897069-04-000546  1255474  WLLAW
#
#                   companyName                 companyNameLong formType  \
# 77345  WHITING PETROLEUM CORP  WHITING PETROLEUM CORP (Filer)     10-K
#
#                                              description  \
# 77345  Form 10-K - Annual report [Section 13 and 15(d...
#
#                          filedAt  \
# 77345  2004-03-04T16:55:25-05:00
#
#                                                linkToTxt  ...  \
# 77345  https://www.sec.gov/Archives/edgar/data/125547...  ...
#
#                                      linkToFilingDetails  \
# 77345  https://www.sec.gov/Archives/edgar/data/125547...
#
#                                                 entities  \
# 77345  [{'fiscalYearEnd': '1231', 'stateOfIncorporati...
#
#                                      documentFormatFiles dataFiles  \
# ...

# %%
df_all.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'id', 'accessionNo', 'cik', 'ticker',
#        'companyName', 'companyNameLong', 'formType', 'description', 'filedAt',
#        'linkToTxt', 'linkToHtml', 'linkToXbrl', 'linkToFilingDetails',
#        'entities', 'documentFormatFiles', 'dataFiles',
#        'seriesAndClassesContractsInformation', 'periodOfReport',
#        'effectivenessDate', '10k_risks1A', '10k_risks7', '10k_risks7A'],
#       dtype='object')

# %%
df_all.set_index('Unnamed: 0.1', inplace=True)

# %%
df_all = df_all.reset_index(drop=True)

# %%
df_all.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df_all.tail(2)
# Out:
#                                      id           accessionNo      cik ticker  \
# 77344  47e80e173f36e2b50dbbb0bd337a0002  0000897069-05-000552  1255474  WLLAW
# 77345  f18ddcaeef0a2485c4be5570750fc362  0000897069-04-000546  1255474  WLLAW
#
#                   companyName                 companyNameLong formType  \
# 77344  WHITING PETROLEUM CORP  WHITING PETROLEUM CORP (Filer)     10-K
# 77345  WHITING PETROLEUM CORP  WHITING PETROLEUM CORP (Filer)     10-K
#
#                                              description  \
# 77344  Form 10-K - Annual report [Section 13 and 15(d...
# 77345  Form 10-K - Annual report [Section 13 and 15(d...
#
#                          filedAt  \
# 77344  2005-02-28T13:24:31-05:00
# 77345  2004-03-04T16:55:25-05:00
#
#                                                linkToTxt  ...  \
# 77344  https://www.sec.gov/Archives/edgar/data/125547...  ...
# 77345  https://www.sec.gov/Archives/edgar/data/125547...  ...
#
# ...

# %%
# #convert df_all to excel
# excel_file_path =r'D:\SEC_RiskData\allRisk.xlsx'
# df_all.to_excel(excel_file_path, index=True)

# %%
df_all.isnull().sum()
# Out:
# id                                          0
# accessionNo                                 0
# cik                                         0
# ticker                                     41
# companyName                                 0
# companyNameLong                             0
# formType                                    0
# description                                 0
# filedAt                                     0
# linkToTxt                                   0
# linkToHtml                                  0
# linkToXbrl                              77346
# linkToFilingDetails                         0
# entities                                    0
# documentFormatFiles                         0
# dataFiles                                   0
# seriesAndClassesContractsInformation    16837
# periodOfReport                          23792
# effectivenessDate                       71196
# 10k_risks1A                              7417
# ...

# %%
#null_values of 1A sanity check
null_1A = df_all[df_all['10k_risks1A'].isnull()]

# %%
null_7 = df_all[df_all['10k_risks7'].isnull()]

# %%
null_7A = df_all[df_all['10k_risks7A'].isnull()]

# %%
null_1A.shape
# Out:
# (7417, 22)

# %%
null_1A.head()
# Out:
#                                   id           accessionNo      cik ticker  \
# 15  e3e6b74a1ce27be5927d81770bcdd823  0001047469-07-009340   320193   AAPL
# 17  29b8e5f1110747563796b245f2744e27  0001104659-05-058421   320193   AAPL
# 18  52071c0e897ae34a2ada14aafcb7f993  0001047469-04-035975   320193   AAPL
# 38  f1f5b1e0c54820e8ae4091277ea3ee60  0001193125-04-150689   789019   MSFT
# 58  61d0841e460a2f249ee41fdb9eb3fe63  0001193125-05-047032  1018724   AMZN
#
#            companyName             companyNameLong formType  \
# 15           APPLE INC           APPLE INC (Filer)     10-K
# 17  APPLE COMPUTER INC  APPLE COMPUTER INC (Filer)     10-K
# 18  APPLE COMPUTER INC  APPLE COMPUTER INC (Filer)     10-K
# 38      MICROSOFT CORP      MICROSOFT CORP (Filer)     10-K
# 58      AMAZON COM INC      AMAZON COM INC (Filer)     10-K
#
#                                           description  \
# 15  Form 10-K - Annual report [Section 13 and 15(d...
# ...

# %%
list(null_1A['filedAt'])
# Out:
# ['2007-11-15T16:49:37-05:00',
#  '2005-11-30T21:22:48-05:00',
#  '2004-12-02T18:05:49-05:00',
#  '2004-09-01T17:03:00-04:00',
#  '2005-03-11T06:20:27-05:00',
#  '2004-02-25T17:25:47-05:00',
#  '2005-03-22T14:33:30-05:00',
#  '2004-03-29T12:31:52-05:00',
#  '2005-09-02T14:17:03-04:00',
#  '2005-02-28T14:42:15-05:00',
#  '2004-09-10T15:48:09-04:00',
#  '2004-02-27T16:10:12-05:00',
#  '2005-03-08T08:01:18-05:00',
#  '2004-03-15T13:43:57-05:00',
#  '2005-03-01T17:14:38-05:00',
#  '2004-03-15T17:10:43-05:00',
#  '2007-02-21T17:22:31-05:00',
#  '2006-03-14T16:15:17-05:00',
#  '2005-03-15T16:26:48-05:00',
#  '2004-03-11T08:55:39-05:00',
#  '2016-02-23T16:17:46-05:00',
#  '2015-02-24T16:04:18-05:00',
#  '2005-03-02T16:42:32-05:00',
#  '2004-02-18T16:17:06-05:00',
#  '2005-02-28T11:31:22-05:00',
#  '2004-03-15T12:53:35-05:00',
#  '2005-03-31T15:34:03-05:00',
#  '2004-04-09T16:05:14-04:00',
#  '2023-02-14T16:48:22-05:00',
#  '2022-02-11T09:52:16-05:00',
#  '2021-02-12T10:44:10-05:00',
# ...

# %%
[list(null_1A['linkToFilingDetails'])][0][75]
# Out:
# 'https://www.sec.gov/Archives/edgar/data/1023052/000118811205000615/t10k-5575.txt'

# %%
ex=null_1A.loc[null_1A['filedAt']=="2023-07-14T16:49:34-04:00"]

# %%
list(ex['linkToFilingDetails'])
# Out:
# ['https://www.sec.gov/Archives/edgar/data/102109/000141057823001476/uuu-20230331x10k.htm']

# %%
#make a list of the companies which do not have 1A, 7 and 7A separately
#notethefrequency of each

# %%
#how many companies have missing risk factors 1A
((null_1A['companyName']).value_counts())
# Out:
# ODYSSEY RE HOLDINGS CORP     114
# PROSPERITY BANCSHARES INC     76
# PHELPS DODGE CORP             56
# AGILENT TECHNOLOGIES INC      55
# CITIGROUP INC                 51
#                             ...
# FULL HOUSE RESORTS INC         1
# American Reprographics CO      1
# PHARMATHENE, INC               1
# AmpliPhi Biosciences Corp      1
# BICYCLE THERAPEUTICS plc       1
# Name: companyName, Length: 2851, dtype: int64

# %%
#study one of the companies which has 1A risk factors absent
null_1A.loc[null_1A['companyName']=="ODYSSEY RE HOLDINGS CORP"].head(2)
# Out:
#                                     id           accessionNo      cik  ticker  \
# 3053  75b1c8a603ae7225cb6923dbf069dd27  0000909567-05-000513  1137048  ORH-PA
# 3054  d120259c89f1a355c638a404c31c0ee4  0000909567-04-000225  1137048  ORH-PA
#
#                    companyName                   companyNameLong formType  \
# 3053  ODYSSEY RE HOLDINGS CORP  ODYSSEY RE HOLDINGS CORP (Filer)     10-K
# 3054  ODYSSEY RE HOLDINGS CORP  ODYSSEY RE HOLDINGS CORP (Filer)     10-K
#
#                                             description  \
# 3053  Form 10-K - Annual report [Section 13 and 15(d...
# 3054  Form 10-K - Annual report [Section 13 and 15(d...
#
#                         filedAt  \
# 3053  2005-03-07T06:59:15-05:00
# 3054  2004-02-17T18:08:18-05:00
#
#                                               linkToTxt  ...  \
# 3053  https://www.sec.gov/Archives/edgar/data/113704...  ...
# 3054  https://www.sec.gov/Archives/edgar/data/113704...  ...
#
# ...

# %%
#companies having missing 7 (top 5)
((null_7['companyName']).value_counts()).head()
# Out:
# PanAmSat Holding CORP          57
# CITIGROUP INC                  51
# BANK OF AMERICA CORP /DE/      28
# STARRETT L S CO                17
# FIRST HORIZON NATIONAL CORP    16
# Name: companyName, dtype: int64

# %%
#number of companies having missing 7A
((null_7A['companyName']).value_counts()).shape
# Out:
# (1225,)

# %%
#EDA on Risk factor 1A

# %%
#create a list of all 1A risks
risk1a=list(df_all['10k_risks1A'])
# print(risk1a[0])

# %%
#plot a word count of each risk factor
# Count words in each paragraph
def word_count(risk):
    return len(risk.split(" "))

#count words for a list of paragraphs
def word_count_list(lis):
    counts=[]
    for item in lis:
        c=len(item.split(" "))
        counts.append(c)
    return counts

# %%
word_count(risk1a[0])
# Out:
# 10226

# %%
word_count_list(risk1a[:5])
# Out:
# [10226, 9664, 8791, 7932, 8000]

# %%
###group all the 1A risk factors by years in ascending order

# %%
df_date=df_all.sort_values(by='filedAt', ascending=True, inplace=False)

# %%
df_date.head(1)
# Out:
#                                      id           accessionNo     cik ticker  \
# 68445  1b27c36e76a04a7af09a4317ebfe6e92  0001096906-04-000005  869495   DWOG
#
#                    companyName                  companyNameLong formType  \
# 68445  DEEP WELL OIL & GAS INC  DEEP WELL OIL & GAS INC (Filer)     10-K
#
#                                              description  \
# 68445  Form 10-K - Annual report [Section 13 and 15(d...
#
#                          filedAt  \
# 68445  2004-01-05T14:28:13-05:00
#
#                                                linkToTxt  ...  \
# 68445  https://www.sec.gov/Archives/edgar/data/869495...  ...
#
#                                      linkToFilingDetails  \
# 68445  https://www.sec.gov/Archives/edgar/data/869495...
#
#                                                 entities  \
# 68445  [{'fiscalYearEnd': '1231', 'stateOfIncorporati...
#
#                                      documentFormatFiles dataFiles  \
# ...

# %%
df_date['10k_risks1A'].tail()
# Out:
# 8575      Item 1A. - Risk Factors \n\n&#160; The follow...
# 12003     ITEM 1A. RISK FACTORS \n\nYou should consider...
# 22855     ITEM 1A. RISK FACTORS \n\nGlobal Risks \n\nGe...
# 15047     ITEM 1A. RISK FACTORS \n\nOur business activi...
# 15849     Item 1A. Risk Factors \n\nSports Business Ris...
# Name: 10k_risks1A, dtype: object
